# %%
import EAtools as ea

# %%
ea.Gnasher("dump TY for 2012-2013 to TY.csv")

# %%
ty = ea.GnashChew("TY.csv")
ty.TY.plot()

# %%
ea.Gnasher("@Regions.txt \n dump reg.NZ.TotalPost96,reg.NI.TotalPost96,reg.SI.TotalPost96 for 2000-2013 to NZ_totals.csv")
NZ_totals = ea.GnashChew("NZ_totals.csv")

# %%
NZ_totals.reg_NZ_TotalPost96.map(lambda x: float(x)).plot()
